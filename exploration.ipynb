# %%
# !python --version
# Out:
# Python 3.13.12

# %%
import pandas as pd
from ydata_profiling import ProfileReport

# Load data
df = pd.read_csv("../../data/primary_studies/Abbott_2019/original/abbott_et_al_2019_cores.csv")

# Generate the report
profile = ProfileReport(df, title="Profiling Report")


# Show it directly in the notebook (or save to HTML)
# profile.to_notebook_iframe()
def hellsdf():
    return

# %%
profile.to_file("EDA/Kacper/ydata_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
